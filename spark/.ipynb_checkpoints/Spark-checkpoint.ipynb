# %% [markdown]
# # Spark
#
# **TODO**:
#
# * Funciones de transformacion
# * Funciones de action
# * Joins
# * SparkSQL
# * Tuning

# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
rdd = sc.textFile('student-mat.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e95f91d03f98> in <module>()
# ----> 1 rdd = sc.read        .format('csv')        .option('header','true')        .load('student-mat.csv')
#
# AttributeError: 'SparkContext' object has no attribute 'read'

# %%
headers = rdd.first().split(',')
headers
# Out:
# ['school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %%
#First field:
rdd.map(lambda x: x.split(',')).take(5)
# Out:
# [['school',
#   'sex',
#   'age',
#   'address',
#   'famsize',
#   'Pstatus',
#   'Medu',
#   'Fedu',
#   'Mjob',
#   'Fjob',
#   'reason',
#   'guardian',
#   'traveltime',
#   'studytime',
#   'failures',
#   'schoolsup',
#   'famsup',
#   'paid',
#   'activities',
#   'nursery',
#   'higher',
#   'internet',
#   'romantic',
#   'famrel',
#   'freetime',
#   'goout',
#   'Dalc',
#   'Walc',
#   'health',
#   'absences',
#   'G1',
#   'G2',
#   'G3'],
#  ['GP',
#   'F',
#   '18',
#   'U',
#   'GT3',
#   'A',
#   '4',
#   '4',
#   'at_home',
#   'teacher',
#   'course',
#   'mother',
#   '2',
#   '2',
#   '0',
#   'yes',
#   'no',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'no',
#   '4',
#   '3',
#   '4',
#   '1',
#   '1',
#   '3',
#   '6',
#   '5',
#   '6',
#   '6'],
#  ['GP',
#   'F',
#   '17',
#   'U',
#   'GT3',
#   'T',
#   '1',
#   '1',
#   'at_home',
#   'other',
#   'course',
#   'father',
#   '1',
#   '2',
#   '0',
#   'no',
#   'yes',
#   'no',
#   'no',
# ...
